# %%
# %load_ext autoreload
# %autoreload 2

# %%
import doralite
import gfdl_utils.core as gu
import xarray as xr

# %%
odiv_projects = doralite.list_project("odiv")['project']
OM5_experiments = [e for e in odiv_projects if e['title'] == "OM5 experiments"][0]['experiments']

# %%
pp = doralite.dora_metadata("odiv-362")['pathPP']

# %%
voi = ["tob"]
for v in voi:
    print(gu.find_variable(pp, v))
# Out:
# ['ocean_monthly']

# %%
out = "ts"
local = gu.get_local(pp, "ocean_monthly", out)

# %%
ppname = "ocean_monthly"
ds = gu.open_frompp(pp, ppname, out, local, "196*", v, dmget=True)
# Out:
# Issuing dmget command to migrate data to disk. Migration complete.

# %%
ds['tob'].isel(time=0).plot()

# %%
gu.get_allvars(pp)
# Out:
# {'ocean_daily': ['mlotst',
#   'omldamax',
#   'tos_max',
#   'sos',
#   'tos_min',
#   'ssu',
#   'tos',
#   'ssv',
#   'ustar',
#   'zos_max',
#   'zos_min',
#   'zos'],
#  'ocean_monthly': ['hfsnthermds',
#   'col_height',
#   'mass_wt',
#   'col_mass',
#   'MLD_003_max',
#   'ePBL_h_ML',
#   'MLD_003_min',
#   'evs',
#   'MLD_003',
#   'ficeberg',
#   'MLD_EN1_max',
#   'friver',
#   'MLD_EN1_min',
#   'fsitherm',
#   'hfsso',
#   'heat_content_cond',
#   'hfrunoffds',
#   'heat_content_fprec',
#   'heat_content_massin',
#   'hf_rvxu_2d',
#   'heat_content_massout',
#   'hf_rvxv_2d',
#   'heat_content_surfwater',
#   'hfsifrazil',
#   'heat_content_vprec',
#   'MLD_EN1',
#   'Heat_PmE',
#   'MLD_EN2',
#   'hf_CAu_2d',
#   'MLD_EN3',
#   'hf_CAv_2d',
#   'hf_u_BT_accel_2d',
#   'hf_diffu_2d',
#   'hf_v_BT_accel_2d',
#   'hf_diffv_2d',
#   'net_massin',
#   'hfds',
#   'intz_CAu_2d',
#   'hf_dudt_2d',
#   'intz_CAv_2d',
#   'hf_du_dt_visc_2d',
#   'intz_gKEv_2d',
#   'hf_dvdt_2d',
#   'intz_PFu_2d',
#   'hf_dv_dt_visc_2d',
#   'net_massout',
#   'hfevapds',
#   'intz_PFv_2d',
#   'hf_gKEu_2d',
#   'intz_rvxu_2d',
#   'hf_gKEv_2d',
#   'intz_rvxv_2d',
#   'hfibthermds',
#   'nonpenSW',
#   'hflso',
#   'opottempmint',
#   'hf_PFu_2d',
#   'pbo',
#   'hf_PFv_2d',
#   'prlq',
#   'hfrainds',
#   'intz_diffu_2d',
#   'intz_u_BT_accel_2d',
#   'intz_diffv_2d',
#   'intz_v_BT_accel_2d',
#   'intz_gKEu_2d',
#   'LwLatSens',
#   'net_heat_coupler',
#   'prsn',
#   'rlntds',
#   'rsdo',
#   'rsntds',
#   'S_adx_2d',
#   'S_ady_2d',
#   'salt_flux_added',
#   'sfdsi',
#   'sob',
#   'somint',
#   'sos',
#   'T_adx_2d',
#   'T_ady_2d',
#   'tauuo',
#   'tauvo',
#   'taux_bot',
#   'taux',
#   'tauy_bot',
#   'tauy',
#   'tob',
#   'tos',
#   'ubt_dt',
#   'umo_2d',
#   'ustar',
#   'vbt_dt',
#   'vmo_2d',
#   'volcello',
#   'vprec',
#   'wfo',
#   'zos'],
#  'ocean_monthly_z': ['osalttend',
#   'agessc',
#   'vert_remap_h_tendency',
#   'boundary_forcing_heat_tendency',
#   'uhml',
#   'boundary_forcing_h_tendency',
#   'vhml',
#   'boundary_forcing_salt_tendency',
#   'rhoinsitu',
#   'dhdt',
#   'rhopot0',
#   'drho_dS',
#   'rhopot2',
#   'drho_dT',
#   'volcello',
#   'dynamics_h_tendency',
#   'rsdoabsorb',
#   'e',
#   'vo',
#   'frazil_heat_tendency',
#   'vmo',
#   'internal_heat_heat_tendency',
#   'rsdo',
#   'obvfsq',
#   'opottempdiff',
#   'opottemppmdiff',
#   'opottemptend',
#   'osaltdiff',
#   'osaltpmdiff',
#   'so',
#   'thetao',
#   'thkcello',
#   'S_advection_xy',
#   'Sh_tendency_vert_remap',
#   'T_advection_xy',
#   'umo',
#   'Th_tendency_vert_remap',
#   'uo'],
#  'ocean_monthly_rho0': ['umo', 'thkcello', 'uhml', 'volcello', 'vhml', 'vmo'],
#  'ocean_monthly_rho2': ['umo', 'thkcello', 'uhml', 'volcello', 'vhml', 'vmo'],
#  'ocean_annual_z': ['volcello',
#   'agessc',
#   'uhml',
#   'boundary_forcing_heat_tendency',
#   'uh',
#   'boundary_forcing_salt_tendency',
#   'vo',
#   'difmxybo',
#   'difvho',
#   'Kd_BBL',
#   'difvso',
#   'vh',
#   'frazil_heat_tendency',
#   'umo',
#   'internal_heat_heat_tendency',
#   'Kd_ePBL',
#   'Kd_interface',
#   'Kd_itides',
#   'Kd_shear',
#   'obvfsq',
#   'opottempdiff',
#   'opottemptend',
#   'osaltdiff',
#   'osaltpmdiff',
#   'osalttend',
#   'rsdoabsorb',
#   'S_advection_xy',
#   'S_adx',
#   'S_ady',
#   'uo',
#   'Sh_tendency_vert_remap',
#   'thetao',
#   'so',
#   'so_xyave',
#   'vmo',
#   'T_advection_xy',
#   'T_adx',
#   'T_ady',
#   'thetao_xyave',
#   'vhml',
#   'Th_tendency_vert_remap'],
#  'ocean_annual': ['LwLatSens',
#   'evs',
#   'friver',
#   'ficeberg',
#   'nonpenSW',
#   'fsitherm',
#   'thetao',
#   'heat_content_cond',
#   'tauvo',
#   'heat_content_fprec',
#   'thkcello',
#   'heat_content_massin',
#   'TKE_itidal',
#   'heat_content_massout',
#   'TKE_tidal',
#   'heat_content_surfwater',
#   'wfo',
#   'heat_content_vprec',
#   'Heat_PmE',
#   'N2_b',
#   'hfds',
#   'hfevapds',
#   'hfibthermds',
#   'net_massin',
#   'hflso',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'hfsnthermds',
#   'prsn',
#   'hfsso',
#   'prlq',
#   'net_heat_coupler',
#   'net_massout',
#   'rlntds',
#   'rsdo',
#   'rsntds',
#   'sfdsi',
#   'so',
#   'salt_flux_added',
#   'tauuo',
#   'ustar',
#   'volcello',
#   'vprec'],
#  'ocean_annual_rho0': ['vmo', 'thkcello', 'volcello', 'uhml', 'vhml', 'umo'],
#  'ocean_annual_rho2': ['vmo', 'thkcello', 'volcello', 'uhml', 'vhml', 'umo'],
#  'ocean_scalar_monthly': ['tosga',
#   'ave_evs',
#   'volo',
#   'ave_hfds',
#   'ave_hflso',
#   'ave_hfsso',
#   'ave_rlntds',
#   'ave_rsntds',
#   'masso',
#   'ave_wfo',
#   'ssh_ga',
#   'LwLatSens_ga',
#   'soga',
#   'net_heat_coupler_ga',
#   'precip_ga',
#   'sosga',
#   'thetaoga'],
#  'ocean_scalar_annual': ['ave_hfds',
#   'ave_evs',
#   'volo',
#   'ave_hflso',
#   'ave_hfsso',
#   'ave_rlntds',
#   'ave_rsntds',
#   'ave_wfo',
#   'LwLatSens_ga',
#   'masso',
#   'thetaoga',
#   'net_heat_coupler_ga',
#   'precip_ga',
#   'soga',
#   'sosga',
#   'ssh_ga',
#   'tosga'],
#  'ice': ['MIB',
#   'ALB',
#   'SSH',
#   'BHEAT',
#   'SSS',
#   'BMELT',
#   'SST',
#   'BSNK',
#   'SNOWFL',
#   'CALVING_HFLX',
#   'SW',
#   'CALVING',
#   'RAIN',
#   'CN',
#   'STRENGTH_hf',
#   'E2MELT',
#   'T1',
#   'EVAP',
#   'T2',
#   'EXT_MAX',
#   'T3',
#   'EXT_MIN',
#   'RUNOFF',
#   'EXT',
#   'T4',
#   'FA_X',
#   'FA_Y',
#   'FI_X',
#   'FI_Y',
#   'FRAZIL',
#   'IX_TRANS',
#   'IY_TRANS',
#   'SALTF',
#   'LH',
#   'LSNK',
#   'LSRC',
#   'SH',
#   'LW',
#   'siconc',
#   'simass',
#   'sisnconc',
#   'sisnmass',
#   'sisnthick',
#   'sispeed',
#   'sitemptop',
#   'sithick',
#   'sitimefrac',
#   'siu',
#   'siv',
#   'sivol',
#   'SN2IC',
#   'TMELT',
#   'TSN',
#   'UO',
#   'VO',
#   'XPRT'],
#  'ocean_daily_1x1deg': [],
#  'ocean_monthly_1x1deg': [],
#  'ocean_monthly_z_1x1deg': [],
#  'ocean_annual_z_1x1deg': [],
#  'ocean_annual_1x1deg': [],
#  'ice_1x1deg': [],
#  'ocean_Barents_opening': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Bering_Strait': ['volcello', 'so', 'vo', 'thetao', 'vmo'],
#  'ocean_Davis_Strait': ['so', 'thetao', 'volcello', 'vmo', 'vo'],
#  'ocean_Windward_Passage': ['volcello', 'so', 'thetao', 'vo', 'vmo'],
#  'ocean_Denmark_Strait': ['so', 'vo', 'thetao', 'vmo', 'volcello'],
#  'ocean_Drake_Passage': ['uo', 'so', 'volcello', 'thetao', 'umo'],
#  'ocean_English_Channel': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Faroe_Scotland': ['volcello', 'so', 'thetao', 'umo', 'uo'],
#  'ocean_Florida_Bahamas': ['volcello', 'so', 'thetao', 'vo', 'vmo'],
#  'ocean_Fram_Strait': ['so', 'thetao', 'volcello', 'vmo', 'vo'],
#  'ocean_Iceland_Faroe_V': [],
#  'ocean_Iceland_Faroe_U': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Indonesian_Throughflow': ['thetao', 'so', 'vmo', 'volcello', 'vo'],
#  'ocean_Mozambique_Channel': ['vo', 'so', 'thetao', 'volcello', 'vmo'],
#  'ocean_Pacific_undercurrent': ['uo', 'so', 'umo', 'thetao', 'volcello'],
#  'ocean_Taiwan_Luzon': ['so', 'thetao', 'uo', 'umo', 'volcello'],
#  'ocean_Agulhas_section': [],
#  'ocean_Gibraltar_Strait': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Iceland_Norway': ['so', 'vo', 'thetao', 'vmo', 'volcello']}

# %%
{e['expName']:e['id'] for e in OM5_experiments}
# Out:
# {'om5_b03_standard_GEBCO_BMv3Ant': 'odiv-368',
#  'om5_b03_bbl01_tidalbg': 'odiv-367',
#  'OM5b03_JRA1.5_GEBCO2023editsBMv3_cycle1': 'odiv-366',
#  'OM5b03_JRA1.5_GEBCO2023edits_cycle1': 'odiv-365',
#  'OM5b03_JRA1.5_GEBCO2023_cycle1': 'odiv-364',
#  'OM5b03_JRA1.5_cycle1_ITRT_noslopeloss_v2': 'odiv-363',
#  'om5_b03_standard_sp_r8_v2': 'odiv-362',
#  'om5_b03_bbl_tidalbg': 'odiv-361',
#  'om5_b00_ryf_branch': 'odiv-360',
#  'om5_b00_ryf': 'odiv-359',
#  'OM5b03_JRA1.5_cycle1_ITRT_noslopeloss': 'odiv-358',
#  'om5_b00_linear': 'odiv-357',
#  'om5_b03_standard_sp_r8_v1': 'odiv-356',
#  'OM5b03_WRIGHT_FULLDT450_cycle1': 'odiv-355',
#  'om5_b03_standard_sp_v5': 'odiv-354',
#  'om5_b03_roquet': 'odiv-353',
#  'OM5b03_ROQUET_cycle1': 'odiv-351',
#  'om5_b00_dtcpld1800_BBLeff0p05': 'odiv-342',
#  'om5_b03_standard_sp_v3': 'odiv-339',
#  'OM5b03_nonBouss': 'odiv-338',
#  'OM5b03_reproducibility_check': 'odiv-337',
#  'OM5b03_abswind': 'odiv-336',
#  'om5_b03_standard_sp_noedits': 'odiv-331',
#  'OM5b03_arahsu90': 'odiv-330',
#  'OM5b03_canonbhsm': 'odiv-329',
#  'OM5b03_purebhsm': 'odiv-328',
#  'om5_b03_WOA23_cycle1': 'odiv-327',
#  'om5_b03_BSGM_c5': 'odiv-326',
#  'om5_b03_GM_c5': 'odiv-325',
#  'om5_b03_BS_c5': 'odiv-324',
#  'om5_b03_standard_sp_v2': 'odiv-323',
#  'om5_b03_standard_sp': 'odiv-322',
#  'om5_b03_WOA18_cycle1': 'odiv-321',
#  'om5_b03_WrightFull': 'odiv-320',
#  'om5_b03_c5': 'odiv-319',
#  'om5_b03_c4': 'odiv-318',
#  'om5_b02_GEBCO2020_nnztools_minthick1em3': 'odiv-317',
#  'om5_b03_cycle1': 'odiv-316',
#  'BUG_om5_b02_minthick1em3_c5': 'odiv-312',
#  'BUG_om5_b02_minthick1em3_c4': 'odiv-311',
#  'om5_b02_GEBCO2020_nnztools_cycle1': 'odiv-309',
#  'om5_b02_kappah2fac1p26': 'odiv-305',
#  'om5_b01_dtrheo3': 'odiv-304',
#  'om5_b01_kappah2fac1p26': 'odiv-303',
#  'om5_b02_cycle1_c5': 'odiv-301',
#  'om5_b02_cycle1_c4': 'odiv-300',
#  'om5_b00_GEBCO2020_nnztools_cycle1': 'odiv-299',
#  'om5_b00_dtcpld1800_BBLeff0_c5': 'odiv-298',
#  'om5_b00_dtcpld1800_BBL_c5': 'odiv-296',
#  'om5_b00_dtcpld1800_BBL_c4': 'odiv-295',
#  'om5_b00_GEBCO2020_om4h2_cycle1': 'odiv-294',
#  'om5_b00_dtcpld1800_c4': 'odiv-291',
#  'om5_b00_dtcpld1800_c5': 'odiv-290',
#  'om5_b00_split4_c4': 'odiv-289',
#  'om5_b00_split3_c4': 'odiv-288',
#  'om5_b00_split2_c4': 'odiv-287',
#  'om5_b00_split1_c4': 'odiv-286',
#  'om5_b00_split4_c5': 'odiv-285',
#  'om5_b00_split3_c5': 'odiv-284',
#  'om5_b00_split2_c5': 'odiv-283',
#  'om5_b00_split1_c5': 'odiv-282',
#  'om5_om4_c4': 'odiv-281',
#  'om5_om4_c5': 'odiv-280',
#  'om5_b00_GEBCO2020_cycle1': 'odiv-279',
#  'om5_b00_minThck0p001001_cycle1': 'odiv-278',
#  'om5_b00_nonBouss_c5': 'odiv-277',
#  'om5_b00_cycle1_c4_repro': 'odiv-276',
#  'BUG_om5_b00_BBL_VS_KV0_MStrC1p25_minThk_Bodner0p03_c4': 'odiv-275',
#  'om5_b00_nonSymmetric': 'odiv-274',
#  'om5_b00_ePBLbisect': 'odiv-273',
#  'BUG_om5_b00_BBL_VS_KV0_MStrC1p25_minThk_Bodner0p03_c5': 'odiv-272',
#  'om5_b00_coorconfigALE': 'odiv-271',
#  'om5_b00_nonBouss_c4': 'odiv-270',
#  'om5_b00_cycle1_c5': 'odiv-269',
#  'om5_b00_cycle1_c4': 'odiv-268'}

# %%
doralite.dora_metadata(2194)
# Out:
# {'displayName': None,
#  'expLabels': None,
#  'expLength': None,
#  'expMIP': None,
#  'expName': 'om5_b02_GEBCO2020_nnztools_cycle1',
#  'expType': None,
#  'expYear': None,
#  'gfdlHistoryYear': None,
#  'id': 2194,
#  'jobID': None,
#  'master_id': '2194',
#  'modelType': 'OM5',
#  'owner': 'Jacob.Steinberg',
#  'pathAnalysis': '/nbhome/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/',
#  'pathDB': '/home/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/gfdl.ncrc5-intel23-prod/db/',
#  'pathLog': None,
#  'pathPP': '/archive/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/gfdl.ncrc5-intel23-prod/pp/',
#  'pathScript': '/lustre/f2/dev/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/ncrc5.intel23-prod/scripts/om5_b02_GEBCO2020_nnztools_cycle1/',
#  'pathXML': '/home/jms/ncrc/om5/ocean-only/b02/om5_b02_GEBCO2020_nnztools.xml/',
#  'queue': None,
#  'refresh': None,
#  'requested_id': '2194',
#  'source': 'sql',
#  'status': None,
#  'urlCurator': None,
#  'userName': 'Jacob.Steinberg',
#  'pathHistory': '/archive/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/gfdl.ncrc5-intel23-prod/history/'}

# %%
odiv_projects = doralite.list_project("odiv")['project']
OM5_experiments = [e for e in odiv_projects if e['title'] == "OM5 experiments"][0]['experiments']

[e for e in OM5_experiments if e["master_id"]==2194][0]
# Out:
# {'displayName': None,
#  'expLabels': None,
#  'expLength': None,
#  'expMIP': None,
#  'expName': 'om5_b02_GEBCO2020_nnztools_cycle1',
#  'expType': None,
#  'expYear': None,
#  'experiment_id': 309,
#  'gfdlHistoryYear': None,
#  'id': 'odiv-309',
#  'jobID': None,
#  'master_id': 2194,
#  'modelType': 'OM5',
#  'owner': 'Jacob.Steinberg',
#  'pathAnalysis': '/nbhome/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/',
#  'pathDB': '/home/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/gfdl.ncrc5-intel23-prod/db/',
#  'pathLog': None,
#  'pathPP': '/archive/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/gfdl.ncrc5-intel23-prod/pp/',
#  'pathScript': '/lustre/f2/dev/Jacob.Steinberg/fre_om5/FMS2023.01_om5_20230927/om5_b02_GEBCO2020_nnztools_cycle1/ncrc5.intel23-prod/scripts/om5_b02_GEBCO2020_nnztools_cycle1',
#  'pathXML': '/home/jms/ncrc/om5/ocean-only/b02/om5_b02_GEBCO2020_nnztools.xml',
#  'queue': None,
#  'refresh': None,
#  'status': None,
#  'urlCurator': None,
#  'userName': 'Jacob.Steinberg'}

# %%
def load(var, exp, ppname="ocean_annual", dmget=True, mirror=False):
    pp = doralite.dora_metadata(exp)['pathPP']
    local = gu.get_local(pp, ppname, "ts")
    path = gu.get_pathspp(pp, ppname, "ts", local, "*", f"*{var}*")
    path_static = gu.get_pathstatic(pp, ppname)
    
    ds = gu.open_frompp(pp, ppname, "ts", local, "*", f"*{var}*", engine="netcdf4", dmget=dmget, mirror=mirror)
    grid = xr.open_dataset(path_static)
    
    return ds, grid

def deep_TKE_itidal(exp, cutoff_depth=2500, timemean=False, dmget=True, mirror=False, dl=8):
    ds, grid = load("TKE_itidal", exp, ppname="ocean_annual", dmget=dmget, mirror=mirror)
    conversion = ds['TKE_itidal']*grid['areacello'].values
    if timemean:
        conversion=conversion.mean('time')

    smoothed_depth = grid.deptho.fillna(0.).rolling({"xh":dl, "yh":dl}).mean()
    
    total_conversion = conversion.sum(["xh", "yh"]).compute() * 1e-12
    deep_conversion = conversion.where(smoothed_depth.values > cutoff_depth).sum(["xh", "yh"]).compute() * 1e-12
    
    return deep_conversion, total_conversion

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 4))
plt.subplot(1,3,2)
plt.axhline(1.0, color="k", linewidth=6, alpha=0.4, label="observational target")
for odiv in ["319", "356"]:
    expName = doralite.dora_metadata(f"odiv-{odiv}")['expName']
    print(expName)
    deep, total = deep_TKE_itidal(f"odiv-{odiv}")

    plt.subplot(1,3,1)
    (total-deep).plot(label=f"{odiv} ({expName})")
    plt.ylabel("Shallow Baroclinic Conversion [TW]")
    
    plt.subplot(1,3,2)
    deep.plot(label=f"{odiv} ({expName})")
    plt.ylabel("Deep Baroclinic Conversion [TW]")
    
    plt.subplot(1,3,3)
    total.plot(label=f"{odiv} ({expName})") # just to be able to distinguish lines
    plt.ylabel("Total Baroclinic Conversion [TW]")

plt.subplot(1,3,2)
plt.legend()
plt.tight_layout()
# Out:
# om5_b03_c5
# Issuing dmget command to migrate data to disk. Migration complete.
# om5_b03_standard_sp_r8_v1
# Issuing dmget command to migrate data to disk. Migration complete.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 4))
for odiv in ["301", "303", "305"]:#, "299",  "309"]:
    expName = doralite.dora_metadata(f"odiv-{odiv}")['expName']
    print(expName)
    deep, total = deep_TKE_itidal(f"odiv-{odiv}", cutoff_depth=400, dl=1)

    plt.subplot(1,3,1)
    (total-deep).plot(label=f"{odiv} ({expName})")
    plt.ylabel("Shallow Baroclinic Conversion [TW]")
    
    plt.subplot(1,3,2)
    deep.plot(label=f"{odiv} ({expName})")
    plt.ylabel("Deep Baroclinic Conversion [TW]")
    
    plt.subplot(1,3,3)
    (total+2e-3*(np.random.rand()-0.5)).plot(label=f"{odiv} ({expName})") # just to be able to distinguish lines
    plt.ylabel("Total Baroclinic Conversion [TW]")
    
plt.legend()
plt.tight_layout()
# Out:
# om5_b02_cycle1_c5
# Issuing dmget command to migrate data to disk. Migration complete.
# om5_b01_kappah2fac1p26
# Issuing dmget command to migrate data to disk. Migration complete.
# om5_b02_kappah2fac1p26
# Issuing dmget command to migrate data to disk. Migration complete.

# %%
ds, grid = load("TKE_itidal", "odiv-305", ppname="ocean_annual")
# Out:
# Issuing dmget command to migrate data to disk. Migration complete.

# %%
import matplotlib

# %%
plt.figure(figsize=(8,4))
ds['TKE_itidal'].mean('time').plot(norm=matplotlib.colors.LogNorm(vmin=1e-3, vmax=1e-1))

# %% [markdown]
# ### CM

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 4))
for odiv in ["1", "302", "314"]:#, "299",  "309"]:
    expName = doralite.dora_metadata(f"odiv-{odiv}")['expName']
    print(expName)
    deep, total = deep_TKE_itidal(f"odiv-{odiv}")

    plt.subplot(1,3,1)
    (total-deep).plot(label=f"{odiv} ({expName})")
    plt.ylabel("Shallow Baroclinic Conversion [TW]")
    
    plt.subplot(1,3,2)
    deep.plot(label=f"{odiv} ({expName})")
    plt.ylabel("Deep Baroclinic Conversion [TW]")
    
    plt.subplot(1,3,3)
    (total+2e-3*(np.random.rand()-0.5)).plot(label=f"{odiv} ({expName})") # just to be able to distinguish lines
    plt.ylabel("Total Baroclinic Conversion [TW]")
    
plt.legend()
plt.tight_layout()
# Out:
# CM4_piControl_C
# Issuing dmget command to migrate data to disk. Migration complete.
# cm_am4c96l33_b02
# Issuing dmget command to migrate data to disk. Migration complete.
# cm_am4c96l33_b02_minthick1mm
# Issuing dmget command to migrate data to disk. Migration complete.
